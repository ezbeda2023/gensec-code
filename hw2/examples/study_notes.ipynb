# %% [markdown]
# # Study notebook
# This demo uses a chunk size of 1200 characters with 200 characters of overlap. Overlap preserves context across chunk boundaries. Chroma stores embeddings and retrieves similar passages.

# %%
chunk_size = 1200
chunk_overlap = 200

# %% [markdown]
# Retrieval-augmented generation retrieves relevant source passages before asking a language model to answer. A citation points the reader to the evidence; it does not guarantee that the model interpreted it correctly.
